# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\Asus\OneDrive\New folder\OneDrive\Desktop\DADV Practicals\quantum-optimizer.xlsx")
data
# Out:
#    Experiment_ID   Optimizer_Type Quantum_Algorithm           Problem_Type  \
# 0         EXP001  GradientDescent              QAOA                 MaxCut
# 1         EXP002             Adam               VQE  PortfolioOptimization
# 2         EXP003           COBYLA              QAOA      TravelingSalesman
# 3         EXP004             SPSA               VQE             IsingModel
# 4         EXP005       NelderMead              QAOA          GraphColoring
# 5         EXP006  GradientDescent               VQE                 MaxCut
# 6         EXP007           COBYLA              QAOA  PortfolioOptimization
# 7         EXP008             Adam               VQE             IsingModel
# 8         EXP009             SPSA              QAOA      TravelingSalesman
# 9         EXP010       NelderMead               VQE          GraphColoring
# 10        EXP011  GradientDescent              QAOA                 MaxCut
# ...

# %%
data.head()
data.plot(kind='bar',x='Problem_Type',y='Success_Probability')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## This is a heading
# This is where I explainn what my chart means
